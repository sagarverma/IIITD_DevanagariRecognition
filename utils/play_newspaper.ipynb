# %%
from os import listdir
import xml.etree.ElementTree as ET
import cv2

# %%
from scipy.ndimage.measurements import label
import numpy as np
from random import shuffle

# %%
import json

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fin1 = open('dataset/digital_words_clean_0_2000.json', 'rb')
#fin2 = open('dataset/digital_words_clean_1000_2000.json', 'rb')
data = json.load(fin1)
#data2 = json.load(fin2)

#data.update(data2)

fin1.close()
#fin2.close()

# %%
out_data = {}
chars = {}
words = {}
for d in data.keys():
    text = data[d]
    chs = list(text)
    for ch in chs:
        if ch not in chars:
            chars[ch] = 1
        else:
            chars[ch] += 1
    text = text.replace('\t', '')
    out_data[d] = text
    
    if text not in words:
        words[text] = 1
    else:
        words[text] += 1
    

#fout = open('dataset/digital_words_clean_0_2000.json', 'wb')
#json.dump(out_data, fout)
#fout.close()

# %%
fout = open('dataset/digital_words_train_test.json','wb')

# %%
dataset = []

for d in data.keys():
    if '\t' not in data[d]:
        dataset.append([d, data[d]])
    
shuffle(dataset)
train = dataset[:int(len(dataset)*0.7)]
test = dataset[int(len(dataset)*0.7):]

print len(train), len(test)
# Out:
# 200550 85951

# %%
out = {}

out['abc'] = ''.join(chars.keys())
out['train'] = [{"text": t[1], "name": t[0] + '.png'} for t in train]
out['test'] = [{"text": t[1], "name": t[0] + '.png'} for t in test]

# %%
json.dump(out, fout)

# %%
fout.close()

# %%
char_dic = {}
for char in chars.keys():
    char_dic['U+%04X' % (ord(char),)] = char
  
print(len(dataset))
print(len(char_dic.keys()))
# Out:
# 286501
# 73

# %%
lst = char_dic.keys()
lst.sort()

for l in lst:
    print l, char_dic[l], chars[char_dic[l]]
# Out:
# U+0901 ँ 8
# U+0902 ं 42875
# U+0903 ः 48
# U+0905 अ 17523
# U+0906 आ 12808
# U+0907 इ 7352
# U+0908 ई 5580
# U+0909 उ 6596
# U+090A ऊ 303
# U+090B ऋ 46
# U+090F ए 13141
# U+0910 ऐ 86
# U+0911 ऑ 716
# U+0913 ओ 2863
# U+0914 औ 192
# U+0915 क 84815
# U+0916 ख 10533
# U+0917 ग 26063
# U+0918 घ 2484
# U+091A च 16150
# U+091B छ 3368
# U+091C ज 35444
# U+091D झ 1553
# U+091E ञ 298
# U+091F ट 18383
# U+0920 ठ 2807
# U+0921 ड 14774
# U+0922 ढ 953
# U+0923 ण 6922
# U+0924 त 50981
# U+0925 थ 5927
# U+0926 द 32456
# U+0927 ध 11279
# U+0928 न 73896
# U+0929 ऩ 3
# U+092A प 40011
# U+092B फ 9677
# U+092C ब 29866
# U+092D भ 10735
# U+092E म 57353
# U+092F य 38281
# U+0930 र 114876
# U+0932 ल 69276
# U+0935 व 52382
# U+0936 श 22835
# U+0937 ष 9654
# U+0938 स 77415
# U+0939 ह 27122
# U+093C ़ 3413
# U+093E ा 161180
# U+093F ि 87471
# U+0940 ी 55985
# U+0941 ु 22893
# U+0942 ू 9119
# U+0943 ृ 1406
# U+0945 ॅ 309
# U+0947 े 49076
# U+0948 ै 6265
# U+0949 ॉ 3124
# U+094B ो 31276
# U+094C ौ 4463
# U+094D ् 78965
# U+0958 क़ 14
# U+0959 ख़ 8
# U+095B ज़ 97
# U+095C ड़ 4032
# U+095D ढ़ 1060
# U+095E फ़ 9
# U+0964 । 9832
# U+0966 ० 7
# U+0967 १ 2
# U+0968 २ 2
# U+096C ६ 1

# %%
print(len(words.keys()))
print(len(dataset))
# Out:
# 117162
# 286501

# %%
DATA_DIR = 'dataset/digital_words/'

for i in range(1,100,10):
    fig = plt.figure(figsize=(20, 10))
    column = 0
    for j in range(10):
        img = cv2.imread(DATA_DIR + dataset[i * 10 + j][0] + '.png')
        img = cv2.resize(img,(160,64))
        column += 1
        fig.add_subplot(1, 10, column)
    
        img = img[1:-15,:,:]
        img = cv2.resize(img, (320,32))
        plt.imshow(img)
        plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-28-c1562f995fbe> in <module>()
#       6     for j in range(10):
#       7         img = cv2.imread(DATA_DIR + dataset[i * 10 + j][0] + '.png')
# ----> 8         img = cv2.resize(img,(160,64))
#       9         column += 1
#      10         fig.add_subplot(1, 10, column)
#
# error: OpenCV(3.4.1-dev) /home/sagan/opencv/modules/imgproc/src/resize.cpp:4044: error: (-215) Assertion failed: ssize.width > 0 && ssize.height > 0 in function resize

# %%
fin = open('dataset/iden', 'r')

shapes = []
for line in fin.readlines():
    shapes.append(map(int, line.split()[2].split('x')))

fin.close()

shapes = np.asarray(shapes)

# %%
print 'max height:', shapes[:, 0].max()
print 'min height:', shapes[:, 0].min()
print 'average height:', np.sum(shapes[:, 0])/shapes.shape[0]

print 'max width:', shapes[:, 1].max()
print 'min width:', shapes[:, 1].min()
print 'average width:', np.sum(shapes[:, 1])/shapes.shape[0]

ratios = np.divide(shapes[:,0], shapes[:,1] * 1.0)
print 'max ratio:', ratios.max()
print 'min ratio:', ratios.min()
print 'average ratio:', np.sum(ratios) / (shapes.shape[0] * 1.0)
# Out:
# max height:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-143c9addbfdd> in <module>()
# ----> 1 print 'max height:', shapes[:, 0].max()
#       2 print 'min height:', shapes[:, 0].min()
#       3 print 'average height:', np.sum(shapes[:, 0])/shapes.shape[0]
#       4
#       5 print 'max width:', shapes[:, 1].max()
#
# NameError: name 'shapes' is not defined

# %%
img = cv2.imread(DATA_DIR + dataset[5][0] + '.png')
plt.imshow(img)

# %%
bottom = img.shape[0]-1
for i in range(img.shape[0]-10):
    if np.count_nonzero(img[i:i+10,:,:]) == (10 * img.shape[1] * img.shape[2]):
        print i
        bottom = i + 5
        
plt.imshow(img[0:bottom,:,:])

# %%
fin = open('dataset/epaper.lst', 'r')

to_download = []
for line in fin.readlines():
    url_parts = line.split('#')
    #print url_parts
    for i in range(1,11):
        date = str(i+1).zfill(2) + '042018'
        
        for j in range(1,16):
            url = url_parts[0] + '/' + date + '/' + str(i) + url_parts[1][:-8] + str(j) + '-0.PDF'
            to_download.append(url)

# %%
fout = open('dataset/download_epaper.lst','w')

i = 1
for i in range(len(to_download)):
    fout.write('wget ' + to_download[i] + ' &\n')
    
    if i % 44 == 0:
        fout.write('wait\n')
    
    i += 1

fout.close()

# %%
import sys
import unicodedata

import regex # $ pip install regex
lst = []
for i in xrange(sys.maxunicode + 1):
    u = unichr(i)
    if regex.match(u"[[:space:]]", u):
        try:
            name = unicodedata.name(u)
        except ValueError:
            name = ""
        lst.append('U+%04X' % (ord(u),))

# %%
print lst

# %%
import PyPDF2

# %%
f = open('temp.pdf', 'rb')

# %%
fileReader = PyPDF2.PdfFileReader(f)

# %%
fileReader.getFields()

# %%
dat = fileReader.getPage(0)

# %%
dat.keys()
# Out:
# ['/Contents',
#  '/Parent',
#  '/TrimBox',
#  '/Resources',
#  '/Rotate',
#  '/CropBox',
#  '/MediaBox',
#  '/ArtBox',
#  '/BleedBox',
#  '/Type']

# %%
resources = dat['/Resources']

# %%
resources.keys()
# Out:
# ['/ColorSpace', '/XObject', '/Font', '/ProcSet', '/ExtGState']

# %%
import textract

# %%
text = textract.process('temp.pdf', method='pdfminer')

# %%
words = text.split()

# %%
len(words)
# Out:
# 1995

# %%
for word in words:
    print word
# Out:
# Sudoku
# :
# 1659
# 7
# 5
# 4
# 2
# 6
# 9
# 3
# 4
# 6
# 5
# 1
# 4
# 1
# 7
# 5
# 4
# 1
# 3
# 9
# 2
# 4
# 5
# 8
# 9
# 6
# 6
# 7
# 5
# 8
# 9
# 1
# 4
# 2
# 1
# 4
# 3
# 1
# 7
# 2
# 5
# 8
# 4
# 9
# 5
# हल-1658
# 9
# 5
# 8
# 6
# 7
# 6
# 3
# 4
# 2
# 7
# 1
# 3
# 1
# 2
# 7
# 6
# 9
# 8
# 4
# 6
# 5
# 7
# 4
# 3
# 1
# 6
# 8
# 5
# 7
# 3
# 4
# 9
# 2
# 8
# 3
# 8
# 5
# 8
# 7
# 3
# 4
# 2
# 1
# 9
# 6
# 2
# 1
# 9
# 5
# 2
# 4
# 1
# 9
# 3
# 6
# 6
# 4
# 9
# 8
# 1
# 5
# 2
# 3
# 7
# 8
# 5
# 9
# 2
# 4
# 3
# 7
# 6
# 1
# 1
# 6
# कैसे
# खेलें
# वगमा
# को
# 1
# से
# ९
# तक
# अंकों
# से
# ऐसे
# भरें
# त्क
# आड़ी
# व
# खड़ी
# पंसकत
# के
# सा्
# ही
# 3
# गुणा
# 3
# के
# बॉकस
# में
# 1
# से
# 9
# तक
# अंक
# आएं।
# कोई
# अंक
# ररपीट
# न
# हो।
# ववविष्ट
# न्या्याल्
# कया
# फैसलया
# भीलवा़िा
# में
# दतलि
# की
# तबंदरोली
# ररोकने
# पर
# 8
# दरोतषर्चों
# करो
# 6
# महीने
# की
# सजा
# लीगल
# ररपरोट्डर
# |
# भीलवा़िा
# वववशषटि
# नरारालिर
# (एससी-एसटिी
# अतराचार
# अवधवनरम)
# ने
# मंगलिवार
# को
# दवलित
# की
# वबंदौलिी
# रोकने
# तथिा
# मेहमानों
# से
# मारपीटि
# के
# 8
# दोवषरों
# को
# 6-6
# माह
# की
# सजा
# सुनाई।
# दोवषरों
# पर
# 2-2
# हजार
# रुपए
# का
# जुमा्यना
# िी
# लिगारा।
# प्कर्ण
# के
# अनुसार,
# 14
# मई
# 2013
# को
# प्ेम
# बलिाई
# ने
# आसींद
# थिाने
# में
# ररपोटि्ट
# दज्य
# कराई।
# वजसमें
# बतारा
# वक
# 12
# मई
# 2013
# को
# उसके
# पुत्र
# बाबू
# लिालि
# का
# वववाह
# थिा।
# एक
# वदन
# पहलिे
# 11
# मई
# रात
# को
# गांव
# में
# बाबू
# लिालि
# को
# घोडी
# पर
# बै्ाकर
# वबंदोलिी
# वनकालिी
# गई।
# इस
# दौरान
# आरोवपरों
# ने
# आगे
# आकर
# वबंदोलिी
# रोक
# दी।
# इस
# दौरान
# गांव
# में
# माहौलि
# गरमा
# गरा।
# सजा
# पाने
# वालिों
# में
# आसींद
# के
# नोलिा
# का
# खेडा
# वनवासी
# लिक्म्ण
# गुज्यर,
# जालिू
# गुज्यर,
# सुखदेव
# गुज्यर,
# लिहरू
# लिालि
# गुज्यर,
# गोपी
# गुज्यर,
# रूपा
# कुमहार,
# देवा
# गुज्यर
# तथिा
# नेनू
# राम
# गुज्यर
# शावमलि
# हैं।
# अजमेर
# पेज
# एक
# का
# शेष...
# राजसिान
# :
# कहीं
# भी...
# दवलित
# आंदोलिन
# में
# सबसे
# जरादा
# प्िाववत
# अलिवर
# वजलिे
# में
# बंद
# का
# असर
# रहा।
# कोटिा,
# सीकर,
# िरतपुर,
# धौलिपुर,
# डू
# ंगरपुर
# सवहत
# कई
# शहरों
# में
# बाजार
# बंद
# रहे।
# जबवक
# जोधपुर,
# अजमेर,
# उदरपुर,
# बांसवाडा,
# झु
# ंझुनू
# ं
# में
# बाजार
# खुलिे
# रहे।
# हनुमानगढ
# एवं
# नीमकाथिाना
# में
# धारा
# 144
# लिागू
# रही।
# गृह
# मंत्री
# गुलिाब
# चंद
# कटिारररा
# ने
# बतारा
# वक
# छुटिपुटि
# घटिनाओं
# को
# छोडकर
# बंद
# के
# दौरान
# कोई
# अवप्र
# घटिना
# नहीं
# हुई।
# हनुमानगढ
# में
# शाम
# पांच
# बजे
# तक
# बाजार
# बंद
# रहे।
# बारां
# एवं
# झालिावाड
# में
# बंद
# का
# वमलिाजुलिा
# असर
# रहा।
# धौलिपुर
# में
# बंद
# का
# असर
# देखा
# गरा।
# रहां
# कोई
# अवप्र
# घटिना
# नहीं
# हुई।
# लिेवकन
# आगरा
# में
# धौलिपुर
# वडपो
# की
# दो
# बसों
# में
# तोडफोड
# की
# गई।
# िरतपुर
# में
# ्वैस्छक
# रूप
# से
# बंद
# रहा।
# अजमेर
# एवं
# चूरू
# में
# बाजार
# खुलिे
# रहे।
# डू
# ंगरपुर
# में
# कुछ
# ्थिानों
# पर
# बंद
# रहा।
# उदरपुर
# संिाग
# में
# बंद
# बेअसर
# वदखा।
# अलिवर
# सवहत
# 15
# क्बों
# में
# बंद
# रहा।
# रहां
# ्कूलि
# एवं
# वरापाररक
# प्वतष्ान
# िी
# बंद
# रहे।
# गंगानगर
# में
# तीन
# घंटिे
# तक
# बंद
# का
# असर
# रहा।
# वफर
# बाजार
# खुलि
# गए।
# अजमेर
# में
# भी
# ...
# बंद
# को
# लिेकर
# कोई
# िी
# संग्न
# सामने
# नहीं
# आरा।
# उधर,
# पुषकर
# में
# िी
# बंद
# बेअसर
# रहा।
# रहां
# बंद
# की
# संिावना
# को
# धरान
# में
# रखते
# हुए
# पुवलिस
# प्शासन
# अलिटि्ट
# रहा।
# अजमेर
# शहर
# के
# सिी
# बाजार,
# सिी
# वशक्ष्ण
# सं्थिाओं
# सवहत
# पररवहन
# साधनों
# का
# संचालिन
# सामानर
# वदनों
# की
# तरह
# बना
# रहा।
# हालिांवक
# बंद
# के
# संदेश
# को
# लिेकर
# वजलिा
# और
# पुवलिस
# प्शासन
# पूरी
# तरह
# मु्तैद
# रहा।
# बंद
# की
# स्थिवत
# से
# वनपटिने
# के
# वलिए
# वजलिा
# प्शासन
# ने
# बंद
# नहीं
# रखने
# की
# अपीलि
# की
# तो
# वहीं
# पुवलिस
# प्शासन
# ने
# िी
# बंद
# के
# दौरान
# हंगामा
# मचाने
# और
# कानून
# वरव्थिा
# को
# प्िाववत
# करने
# वालिों
# के
# वखलिाफ
# सखती
# से
# कार्यवाई
# के
# वनददेश
# वदए
# थिे।
# पुवलिस
# की
# सखती
# के
# चलिते
# वजलिेिर
# में
# कहीं
# िी
# बंद
# समथि्यक
# और
# ववरोधी
# सामने
# नहीं
# आए।
# अजमेर,
# बुधवार
# 11
# अप्रैल,
# 2018
# |
# 8
# पूव्च
# उपसभापति
# चौधरी...
# फोन
# करने
# वालिों
# ने
# खुद
# को
# जेलि
# में
# बंद
# राम्वरूप
# गजनी
# बताते
# हुए
# पचास
# लिाख
# रुपए
# मांगे
# थिे।
# वजसकी
# वशकारत
# चौधरी
# ने
# गांधीनगर
# थिाना
# पुवलिस
# में
# की
# थिी।
# फारर
# की
# सूचना
# पर
# पुवलिस
# उपाधीक्षक
# ओमप्काश
# वकलिावनरा,
# मदनगंज
# थिाना
# प्िारी
# जोगेंद्र
# वसंह
# व
# गांधीनगर
# थिाना
# पुवलिस
# मौके
# पर
# पहु
# ंची।
# पुवलिस
# को
# मौके
# से
# गोलिी
# के
# पांच
# खोलि
# बरामद
# हुए
# हैं।
# फारर
# देसी
# कट्
# टिे
# व
# वप्टिलि
# से
# करना
# बतारा
# जा
# रहा
# है।
# जानकारी
# के
# अनुसार
# पूव्य
# उपसिापवत
# प्दीप
# चौधरी
# प्ोपटिटी
# वरवसारी
# िी
# हैं।
# चौधरी
# के
# पास
# सोमवार
# को
# शाम
# 4
# बजे
# मोबाइलि
# पर
# कॉलि
# आरा
# थिा।
# कॉलि
# करने
# वालिे
# ने
# खुद
# को
# अजमेर
# जेलि
# में
# बंद
# राम्वरूप
# गजनी
# बताते
# हुए
# पचास
# लिाख
# रुपए
# की
# वफरौती
# मांगी
# थिी।
# पैसे
# नहीं
# देने
# पर
# जान
# से
# मारने
# की
# धमकी
# दी
# थिी।
# चौधरी
# ने
# गांधीनगर
# थिाना
# पुवलिस
# को
# इसकी
# वशकारत
# दी
# थिी।
# उसके
# बाद
# मंगलिवार
# रात
# 9
# बजे
# कॉलिोनी
# में
# स्थित
# जैन
# मंवदर
# में
# दश्यनाे
# ं
# के
# वलिए
# गए
# थिे।
# पीछे
# से
# मकान
# में
# चौधरी
# का
# पुत्र
# अररहंत
# मौजूद
# थिा।
# तिी
# बाइक
# पर
# सवार
# होकर
# दो
# नकाबपोश
# आए
# और
# मकान
# के
# अंदर
# घुस
# दरवाजा
# खटिखटिारा।
# अररहंत
# ने
# दरवाजा
# खोलिा
# तो
# हवथिरारबंद
# नकाबपोश
# को
# देखकर
# वह
# घबरा
# गरा।
# इसी
# बीच
# बदमाशों
# ने
# मकान
# के
# िीतर
# फारर
# करना
# शुरू
# कर
# वदरा।
# हवा
# में
# फारर
# कर
# वचललिाते
# हुए
# बदमाश
# मकान
# से
# बाहर
# आए
# और
# कार
# पर
# फारर
# करते
# हुए
# बाइक
# पर
# बै्कर
# फरार
# हो
# गए।
# इस
# तरह
# बदमाशाे
# ं
# ने
# कुलि
# पांच
# फारर
# वकए।
# फारररंग
# की
# आवाज
# सुनकर
# मोहललिेवासी
# जमा
# हो
# गए
# और
# लिोगाे
# ं
# में
# दहशत
# का
# माहौलि
# हो
# गरा।
# सूचना
# पर
# पुवलिस
# मौके
# पर
# पहु
# ंची
# और
# घटिना्थिलि
# का
# जारजा
# वलिरा।
# पुवलिस
# ने
# मौके
# से
# पांच
# गोलिी
# के
# खोलि
# बरामद
# वकए।
# फारररंग
# देसी
# कट्
# टिा
# व
# वप्टिलि
# से
# होना
# बतारा
# जा
# रहा
# है।
# कार
# पर
# फारररंग
# से
# शीशा
# क्षवतग्र्त
# हो
# गरा।
# पुवलिस
# बदमाशों
# की
# तलिाश
# में
# जुटिी
# है।
# तिति
# संवत्
# वैशाख,
# कृष्ण
# पक्ष
# दशमी
# बुधवार
# प्ात:
# 06:41
# तक
# रहेगी,
# ववक्रम
# संवत्
# 2075,
# शाके
# 1940,
# वहजरी
# सन
# 1439,
# मुस्लिम
# माह
# रज्जब
# तारीख
# 24,
# सूर्य
# उत्तरार्ण,
# बसंत
# ऋतु,
# 11
# अप्ैलि।
# सूर्योदर्
# कालीन
# नक्षत्र
# धवनष्ा
# नक्षत्र
# रावत्र
# 01:40
# तक,
# इसके
# बाद
# शतविषा
# नक्षत्र
# रहेगा।
# शुि
# रोग
# रावत्र
# बाद
# प्ात:
# 05:41
# तक,
# इसके
# बाद
# शुकलि
# रोग
# रहेगा।
# ववसषटि
# कर्ण
# प्ात:
# 06:41
# तक,
# इसके
# बाद
# बव
# कर्ण
# रहेगा।
# ग्रह
# तवचार
# (प्ाि:
# 05:30)
# सूर्य-मीन,
# चंद्र-मकर,
# मंगलि-धनु,
# बुध-मीन,
# गुरु-तुलिा,
# शुक्र-मेष,
# शवन-धनु,
# राहु-कक्क,
# केतु-मकर
# रावश
# में
# स्थित
# हैं।
# तदशाशूल
# उत्तर
# वदशा
# की
# तरफ
# रहेगा।
# रवद
# जरूरी
# हो
# तो
# दूध
# पीकर
# रात्रा
# कर
# सकते
# हैं।
# राहुकाल
# (मधर्म
# मान
# के
# अनुसार)
# दोपहर
# 12:00
# से
# 01:30
# तक
# शुभाशुभ
# ज्ानम्
# िद्रा
# प्ात:
# 06:41
# तक,
# महातमा
# जरोवतबा
# फूलिे
# जरंती,
# दशमी
# वतवथि
# वृवधि,
# पंचक
# दोपहर
# 12:37
# से।
# चौघत़िर्ा
# मुहूि्च
# प्ात:
# 06:11
# से
# 09:20
# तक
# लिाि
# व
# अमृत
# का
# चौघवडरा,
# सुबह
# 10:54
# से
# 12:28
# तक
# शुि
# का
# चौघवडरा,
# दोपहर
# 03:36
# से
# सारं
# 05:11
# तक
# चर
# का
# चौघवडरा,
# सारं
# 05:11
# से
# 06:45
# तक
# लिाि
# का
# चौघवडरा
# रहेगा।
# आज
# जनमे
# बच्चों
# का
# नामाक्षर
# समर्
# रातश
# जनमाक्षर
# 06:11
# ताम्र
# मकर
# वग
# 12:37
# ताम्र
# कु
# ंि
# गु
# ंि
# गे
# 19:10
# ताम्र
# कु
# 01:40
# ताम्र
# कु
# ंि
# गो
# आज
# तवशेष
# आज
# शुि
# रोग
# में
# पुषप
# दान
# करना
# शुि
# फलिदारी
# है।
# धवनष्ा
# नक्षत्र
# में
# आ्
# वसुओं
# का
# उत्तम
# प्कार
# के
# गंध,
# फलि,
# फूलि,
# धूप,
# दीप,
# नैवेद्य
# आवद
# से
# पूजन
# कर
# व्रत
# करें,
# तो
# सम्त
# मनोकामनाएं
# पूरी
# होती
# हैं।
# पार्ा
# पंतरि
# प्रो.
# तवनरोद
# शासत्री
# रातशफल
# जानकर
# अपनी
# त्दनचयामा
# तय
# करने
# वाले
# लोगों
# के
# त्लए
# प्ो.
# शासत्ी
# बता
# रहे
# हैं
# त्क
# बुधवार
# का
# त्दन
# आपके
# त्लए
# कैसा
# रहेगा।
# इस
# जानकारी
# के
# बाद
# आप
# आने
# वाली
# समसयाओं
# पर
# त्नयंत्ण
# रख
# सकते
# हैं।
# अपनी
# अचछाइयों
# के
# प्त्तशत
# में
# बढ़ोतरी
# भी
# कर
# सकते
# हैं।
# मेष
# (21
# माच्च
# से
# 20
# अप्रैल)
# स्ायी
# संपत्ति
# लाभदायक
# रहेगी।
# नवत्नमामाण
# की
# रूपरेखा
# बन
# सकती
# हरै।
# गुपत
# शत्ु
# आपके
# त्मत्
# ही
# हैं
# उनसे
# सावधानी
# बरतें।
# यात्ा
# हो
# सकती
# हरै।
# शुभ
# अंक
# :
# 5
# |
# रंग
# :
# सलेटी
# तमिुन
# (22
# मई
# से
# 21
# जून)
# आपके
# आसपास
# नकारातमक
# सोच
# के
# लोगों
# का
# बोलबाला
# हरै,
# धीरे-धीरे
# उनसे
# दूररयां
# बना
# लें।
# वाहन
# खरीदने
# का
# मन
# बनेगा।
# त्फजूल
# खचमा
# से
# बचें।
# शुभ
# अंक
# :
# 9
# |
# रंग
# :
# सफेद
# तसंह
# (23
# जुलाई
# से
# 23
# अगसि)
# वरैवात्हक
# चचामाओं
# में
# सफलता
# त्मलेगी।
# अधययन.
# अधयापन
# एवं
# अनुसंधान
# में
# भी
# रुत्च
# बढ़
# सकती
# हरै।
# युवा
# मनचाहा
# काम
# त्मलने
# से
# उतसात्हत
# रहेंगे।
# शुभ
# अंक
# :
# 4|
# रंग
# :
# काला
# िुला
# (24
# तसिंबर
# से
# 23
# अकटटूबर)
# बड़े-बुजुगगों
# से
# सलाह-मशत्वरा
# करके
# घरेलू
# व
# वयापाररक
# त्नणमाय
# लें।
# प्ेम-प्संग
# में
# त्नराशा
# हा्
# लगेगी।
# राजकीय
# मामले
# पक्ष
# में
# हल
# होंगे।
# शुभ
# अंक
# :
# 6
# |
# रंग
# :
# नीला
# धनु
# (23
# नवंबर
# से
# 21
# तदसंबर)
# हरैत्सयत
# के
# त्हसाब
# से
# काम
# शुरू
# करें,
# तनाव
# कम
# होगा।
# त्वद्ात््मायों
# को
# अधययन
# में
# बाधाओं
# का
# सामना
# करना
# पड़ेगा।
# धममा
# में
# आस्ा
# बढ़ेगी।
# शुभ
# अंक
# :
# 5
# |
# रंग
# :
# गुलाबी
# कु
# ंभ
# (21
# जनवरी
# से
# 18
# फरवरी)
# सवास्थय
# में
# सुधार
# होगा।
# अपनों
# के
# सा्
# रहने
# का
# सुखद
# अनुभव
# प्ापत
# करेंगे।
# भावी
# योजनाओं
# के
# नए
# आधार
# त्मलेंगे।
# आय
# के
# स्ोत
# बढ़ं
# शुभ
# अंक
# :
# 7
# |
# रंग
# :
# आसमानी
# ेगे।
# वृष
# (21
# अप्रैल
# से
# 21
# मई)
# धात्ममाक
# उतसवों
# में
# खचमा
# के
# सा्
# वयसतता
# भी
# बढ़ेगी।
# भावनाओं
# पर
# काबू
# रखें
# नहीं
# तो
# परेशानी
# होगी।
# आकससमक
# लाभ
# के
# चककर
# में
# नुकसान
# कर
# लेंगे।
# शुभ
# अंक
# :
# 3
# |
# रंग
# :
# जामुनी
# कक्क
# (22
# जून
# से
# 22
# जुलाई)
# आतमत्वशवास
# की
# कमी
# के
# कारण
# काम
# में
# देरी
# होगी।
# सहकत्ममायों
# को
# अपना
# बनाने
# का
# प्यास
# करें।
# त्शक्षा
# के
# क्षेत्
# में
# सफलता
# त्मल
# सकती
# हरै।
# शुभ
# अंक
# :
# 7
# |
# रंग
# :
# हरा
# कनर्ा
# (24
# अगसि
# से
# 23
# तसिंबर)
# पढ़ाई
# के
# बोझ
# के
# कारण
# सेहत
# का
# धयान
# नहीं
# रख
# पाएंगे।
# धात्ममाक
# अनुष्ानों
# में
# रुत्च
# बढ़ेगी।
# खचमा
# की
# अत्धकता
# से
# बजट
# गड़बड़ा
# सकता
# हरै।
# शुभ
# अंक
# :
# 2
# |
# रंग
# :
# हरा
# वृश्चक(24
# अकटटूबर
# से
# 22
# नवंबर)
# धन
# कमाने
# की
# होड़
# में
# आप
# गलत
# रासते
# पर
# जा
# सकते
# हैं।
# जरूरतमंदों
# की
# मदद
# करके
# खुश
# होंगे।
# जमीन-
# जायदाद
# के
# सौदों
# में
# सावधानी
# बरतें।
# शुभ
# अंक
# :
# 8
# |
# रंग
# :
# लाल
# मकर
# (22
# तदसंबर
# से
# 20
# जनवरी)
# नई
# वयावसात्यक
# गत्तत्वत्ध
# शुरू
# करने
# का
# मन
# बनेगा।
# अपनों
# की
# खुशी
# के
# त्लए
# कुछ
# भी
# करने
# को
# तरैयार
# रहेंगे।
# वाणी
# पर
# त्नयंत्ण
# रखें।
# शुभ
# अंक
# :
# 1
# |
# रंग
# :
# बादामी
# मीन
# (19
# फरवरी
# से
# 20
# माच्च)
# वयापार,
# उद्ोग
# एवं
# रोजगार
# में
# नए
# अवसर
# खुत्शयां
# देंगे।
# राजकाज
# एवं
# नयायालय
# में
# आ
# रही
# बाधाएं
# दूर
# होंगी।
# त्प्यजन
# से
# मुलाकात
# सुखद
# रहेगी।
# शुभ
# अंक
# :
# 3
# |
# रंग
# :
# मरून
# कल
# का
# रातशफल
# आज
# ही
# पति़ए
# www.dainikbhaskar.com
# पर
# क्रॉस
# वर्ड
# 4719
# 3
# 8
# 10
# 17
# 27
# 30
# 11
# 23
# 28
# 16
# 22
# 20
# 31
# 4
# 9
# 10
# 17
# 20
# 32
# 6
# 8
# 13
# 18
# 24
# 25
# 5
# 12
# 18
# 29
# 26
# 2
# 1
# 7
# 14
# 15
# 14
# 19
# 21
# 26
# 33
# बनाना
# (3,3)
# बाएं
# से
# दाएं
# 1.
# हरकत,
# चालि,
# मुसकत
# (2)
# 3.
# साथि्यक
# बनाना,
# कामराब
# 7.
# मेघ,
# पानी
# के
# वाहक
# (4)
# 9.
# परा्यपत,
# रथिेषटि,
# वसफ्क,
# केवलि
# (2)
# 10.
# मनुषर
# (3)
# 12.
# अविनर,
# मंचन
# रोगर
# रचना
# (3)
# 14.
# ववशव,
# संसार
# (2)
# 16.
# वनबटिाना,
# काम
# को
# चलिाना
# (3)
# 18.
# क्ण,
# प्साद,िीख,
# कान
# (2)
# 19.
# कमजोर
# (3)
# 20.
# शराब,
# मद्य
# (3)
# 21.
# पवन,
# वारु
# (2)
# 22.
# नेता,
# अवधपवत,
# मुर
# पात्र
# (3)
# 24.
# सु
# 26.
# मोटिे
# कपडे
# की
# दीवार
# (3)
# 28.
# प्ा्णांत
# होना,
# जीवन
# का
# अंत
# 30.
# अंत:कर्ण,
# वचत्त
# (2)
# 32.
# घटिना,
# दुघ्यटिना
# (4)
# 33.
# अवकाश
# रा
# वरवतक्रम
# करवाना
# (2,4)
# ऊपर
# से
# नीचे
# 1.
# ववशालिकार
# हाथिी
# (4)
# 2.
# तवचा
# पर
# वबंदी
# के
# आकार
# का
# दाग
# (2)
# 3.
# झेलिना,
# सहना
# (3,3)
# 4.
# हों्
# (2)
# ंघनी,
# नसवार
# (2)
# होना
# (3)
# विडना
# (4)
# 5.
# रहना,
# वनवास
# करना,
# आबाद
# होना
# (3)
# 6.
# नाम
# प््ताववत
# करना,
# पंजी
# में
# नाम
# चढाना,
# नामजदगी
# (4)
# 8.
# मवहलिा,
# ्त्री,
# दुगा्य
# (2)
# 11.
# देवता
# से
# वमलिी
# वसवधि,
# दूलहा,
# श्ेष्
# (2)
# 13.
# वमलिना,
# िेंटि
# हो
# जाना,
# टिककर
# मारना,
# 15.
# वपघलिवाना,
# खराब
# कराना
# (4)
# 17.
# प्वसवधि
# वदलिाना,
# वकसी
# को
# संपवत्त
# वदलिवाना,
# वलिखवाना
# (2,4)
# 21.
# रुक-रुककर
# रा
# अटिक
# कर
# बोलिना
# (4)
# 23.
# जुडवां,
# मृतरुदेव
# (2)
# 25.
# एक
# समान
# दूरी
# पर
# स्थित
# (4)
# 27.
# जोश,
# उद्ेग,
# ताव,
# तेजी,
# तीव्रता
# (3)
# 29.
# नाड,
# गलिा,
# जुलिाहों
# की
# ढरकी,
# ्त्री
# (2)
# 31.
# पुरुष
# (2)
# सही
# हल
# क्रॉस
# वर्ड
# |
# 4718
# १अ
# टा
# 4फ
# 3छ
# 6रा
# 4पा
# स
# 2प
# ट
# 5अ
# त्व
# 6र
# ल
# ना
# 8पा
# र
# धा
# त
# 8क
# ट
# 9ह
# क
# 10ला
# 7ब
# नु
# ना
# न12का
# 13क्ष
# सय
# नी
# 15स
# 11प
# ज
# रा
# ष्ा
# 15न
# 16ज्ा
# 16अ
# 13क
# ड़ा
# 14म
# न
# ड़17ची
# 19श
# 18क
# त
# 19र
# ना
# मा
# बू
# त्ध
# 22ग
# म
# 20ना
# 21म
# ्ा
# र
# क
# ट
# 25क
# 25द
# 29दा
# 24ल
# ड़
# न
# ना
# 28ना
# 26जा
# ना
# 27आ
# जा
# ना
# गा
# क25श23ला
# द
# ना
# र

# %%
import pdfplumber
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-b3d6737fd8e1> in <module>()
# ----> 1 import pdfplumber
#
# ImportError: No module named 'pdfplumber'

# %%
# !wget
# Out:
# char_classifier.py  data_clean.ipynb	     resnet.py
# convert.py	    eccv2014_textspotting    text_spot.py
# crnn-pytorch	    extract_from_digital.py
# data_check.ipynb    play_newspaper.ipynb

# %%
print u'\u092C\u0945\u091A'
# Out:
# बॅच

# %%
print u'\u0915\u0938\u093E\u0924\u094D\u0915\u093f\u0928\u093e'
# Out:
# कसात्किना

# %%
print u'\u092a\u094d\u0930\u0924\u093f\u0938\u094d\u092a\u094d\u0930\u0927\u093e\u0905\u093e\u0947\u0902'
# Out:
# प्रतिस्प्रधाअाें

# %%
print u'\u0907\u0902\u091c\u0940\u0928\u093f\u092f\u0930\u093e\u0947\u0902'
# Out:
# इंजीनियराें

# %%
print u'\u090f\u0917\u094d\u091c\u093f\u0915\u094d\u092f\u0942\u091f\u093f\u0935'
# Out:
# एग्जिक्यूटिव

# %%
print u'\u092a\u092a\u093e\u0945\u0928'
# Out:
# पपाॅन

# %%
बिजनेस 
डिजाइन 
डिजाइनर
होम्योपैथी 
सिलेब्रिटीज
इन्वेस्टर्स 
न्यूज़पॉइंट 
पुष्कर्णा
बॅच
दम्पतियों
जाँच
अपोइन्टमेन्ट 
जीतीं
सेवास्तोवा
कसात्किना
सूचना
प्रतिस्प्रधाअाें
आमंत्रित 
प्रतिस्पर्धाएं 
अंतर्राष्ट्रीय 
संवाददाता
वेबसाईट 
कम
कंपोजीशन
स्कीम
एमटीएनएल
की 
इंजीनियराें
कम्यूटिंग 
एजेंसियां 
ख़ुशी 
टैलेंट 
ख़ुदकुशी 
बालों
पुलिसकर्मियों 
रिकॉर्डिंग 
एग्जिक्यूटिव
खिलाफ 
वाट्सएप
फर्टिलाइजर 
सितंबर
व्यवसायियों 
पुनरीक्षण 
गुणवत्ता 
डब्लूएचओ 
शोपियां
ज़िंदगियाँ
योजनाएं
खत्म
मंत्रालय 
नवनिर्वाचित 
प्रक्रिया 
प्रॉफ़िट
पुष्टि 
एसएन 
सीबीआइ
फेरों
निरस्तीकरण 
पश्चिमांचल 
सूचना 
नकल
विद्यार्थियों 
विद्यार्थी 
स्वच्छता 
सूचना 
कठघरे
व्यवस्था 
टूर्बो
स्वच्छता 
भ्रमण 
एवं 
प्लांट 
समय 
अपराह्न 
कुण्ड
लक्ष्मी 
श्रीकान्त
फरवरी 
आइएएस
प्रदूषण
किसानी 
किसानों
कार्यशालाएं 
अन्तर्राष्ट्रीय
इलैक्ट्रॉनिक
अनुसार 
पुलिसकर्मियों 
में 
माफी
नहीं 
रद
निमंत्रण 
अधिसूचना 
रेलगाड़ियों 
अधिग्रहण 
उत्तर रेलवे 
संसाधन 
नेवीगेशन
एप्लीकेशन
टेस्टीमोनियल्स 
सीबीआइ 
आवृत्ति 
एफआइपीबी
वित्तमंत्री 
कैरेक्टर 
एड्रेस 
हसीन
पुष्टि 
बल्कि 
स्कूल 
धौनी
वेबसाईट
अरुणाचल 
एक्सप्रेस 
अरुणाचल 
रैक्सील
अधिगृहीत
शैक्षणिक 
आस्ट्रेलिया
उपराष्ट्रपति 
असवेदनशीलता
जिलाधिकारीय 
कोफमो
एडमिन 
सूचना 
बेंगलूरु
ब्यौरा 
करूंगा
कांफ्रेंसिंग 
हेतु 
केन्द्रीय
निम्नहस्ताक्षरी 
हस्ताक्षरित 
हिप्रलोनिवि 
हाइड्रोलिक 
निम्निलिखित 
आनलाइन
निविदाओं 
नक्सली 
कैम्पस
खोड़ा
आरबीआइ
एलओयू 
बाजारों 
सुविधाएं 
प्रक्रिया 
इलाकों
व्यापारियों 
दुकानें
गलतियों 
व्यापारियों 
गतिविधियों 
गतिविधियां
कॉलेज 
असिस्टेंट
जेएनयू 
बदसुलूकी 
फेल 
छात्रों 
खादी
नाइजीरियाई 
कॉलोनी
सूचना 
मजदुर 
किलोमीटर 
अनुमति 
जुर्माना
स्थिति 
पहली 
महिलाएं
सेवांए
विश्वविद्यालय 
सूचना 
अन्तगर्त
क्योंकि 
कार्यक्रमों 
ढूंढ़ा
सुधारने
लड़ाइया
जाचकर्ताओं
उचाई 
महत्वपूर्ण 
पॉयजन
घोषणापत्र 
डब्ल्यूएचओ 
असिस्टेंट 
सेंसिटिविटी 
असिस्टेंट 
पुरस्कार 
रवींद्रनाथ
हाफीज
सर्वाधिक 
ऑर्गेनाइजेशन 
सम्मेलन 
बम्बावले
डायग्नोसिस
परिक्षण 
प्रोसीजर्स
सुप्रीम कोर्ट 
नैशनल
एयरपोर्ट 
क्लाइमैक्स
बेटियों 
मामला 
बेटियों 
पुष्टि 
एयरलाइंस 
इंटरनैशनल
सूझबूझ 
आवाज 
सृजनात्मक 
दृश्यों 
थियेटर 
कला 
खुदकशी 
ट्रेन
कपड़ा
रक्तस्त्राव 
पपाॅन
प्लेबॉय 
स्टेशनों 
रिडिवेलपमेंट 
कर्मचारिय 
इनसानों
भावनाएं
फिल्मों
डिजाइनर्स 
गर्लफ्रेंड 
बॉलिवुड
सिंगापुर
आइएएस
मुआयना 
सेक्रेटरी 
कर्मचारियों
